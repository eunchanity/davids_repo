# %% [markdown]
# # Web Scraping: Selenium
# _Automate your browser._ <br>
# _Collect data from dynamically generated web pages or those requiring user interaction._
#
# ### Docs
#
# - [Selenium homepage](https://www.seleniumhq.org/)
# - [Selenium documentation](https://selenium-python.readthedocs.io/) - unofficial, but helpful
#
# ### Installation
#
# With conda:
# - `conda install -c conda-forge selenium`
#
# With pip:
# - `pip install -U selenium`
#
# #### ChromeDriver
#
# You will also need to install a web driver to use Selenium.  ChromeDriver is recommended but others are also available.
#
# 1. Check your browser's version _(Chrome > About Google Chrome)_
# ![Browser Version](images/browser_version.png)
# <br>
# 2. Navigate to the [ChromeDriver downloads page](https://sites.google.com/a/chromium.org/chromedriver/downloads).
# <br><br>
# 3. Download appropriately based on your browser's version and your OS.
# ![Download ChromeDriver zip file](images/chromedriver_options.png)
#
# 4. Unzip the driver.
# <br><br>
# 5. Move to Applications folder (or wherever your Chrome application is).

# %%
from bs4 import BeautifulSoup
import requests
import time, os

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

chromedriver = "/Applications/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

# %% [markdown]
# ## Example 1 - YouTube
#
# ### Dynamic Pages
#
# Some pages serve their content dynamically, which means they could look different each time they are loaded into the browser.  HTML that you see by inspecting elements in your browser might be missing from `requests` and `BeautifulSoup` because it is generated at access time.

# %%
query = "data science"
youtube_search = "https://www.youtube.com/results?search_query="
youtube_query = youtube_search + query.replace(' ', '+')

# %%
page = requests.get(youtube_query).text
soup = BeautifulSoup(page, 'html5lib')

# %%
soup.find('div', id='contents')

# %% [markdown]
# Uh oh.  The video links should be under the contents div, but it's missing from our request.
#
# > **QUESTION**: Why do you think this happened?

# %% [markdown]
# One option is to first load the page with Selenium THEN parse the page's HTML with BeautifulSoup.
#
# First we launch the YouTube search page through our ChromeDrive.  A new browser should pop up.  **To continue using Selenium, keep this window open!**

# %%
driver = webdriver.Chrome(chromedriver)
driver.get(youtube_query)

# %% [markdown]
# We can access the page's HTML through the driver:

# %%
driver.page_source[:1000]
# Out:
# '<html style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" lang="en-US" dir="ltr" gl="US"><head><script data-original-src="/s/player/54668ca9/player_ias.vflset/en_US/miniplayer.js" src="/s/player/54668ca9/player_ias.vflset/en_US/miniplayer.js"></script><script data-original-src="/s/player/54668ca9/player_ias.vflset/en_US/remote.js" src="/s/player/54668ca9/player_ias.vflset/en_US/remote.js"></script><meta http-equiv="origin-trial" data-feature="Web Components V0" data-expires="2020-10-23" content="AhbmRDASY7NuOZD9cFMgQihZ+mQpCwa8WTGdTx82vSar9ddBQbziBfZXZg+ScofvEZDdHQNCEwz4yM7HjBS9RgkAAABneyJvcmlnaW4iOiJodHRwczovL3lvdXR1YmUuY29tOjQ0MyIsImZlYXR1cmUiOiJXZWJDb21wb25lbnRzVjAiLCJleHBpcnkiOjE2MDM0ODY4NTYsImlzU3ViZG9tYWluIjp0cnVlfQ=="><meta http-equiv="origin-trial" data-feature="Web Components V0" data-expires="2020-10-27" content="Av2+1qfUp3MwEfAFcCccykS1qFmvLiCrMZ//pHQKnRZWG9dldVo8HYuJmGj2wZ7nDg+xE4RQMQ+Ku1zKM3PvYAIAAABmeyJvcmlnaW4iOiJodHRwczovL2dvb2dsZS5jb206NDQzIiwiZmVhdHVyZSI6I'

# %% [markdown]
# Now we parse this with `BeautifulSoup` and the video information appears!

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
soup.find('div', id='contents')
# Out:
# <div class="style-scope ytd-section-list-renderer" id="contents"><ytd-item-section-renderer class="style-scope ytd-section-list-renderer" use-height-hack=""><!--css-build:shady-->
# <div class="style-scope ytd-item-section-renderer" id="header"></div>
# <div class="style-scope ytd-item-section-renderer" id="spinner-container">
# <paper-spinner-lite aria-hidden="true" class="style-scope ytd-item-section-renderer"><!--css-build:shady--><div class="style-scope paper-spinner-lite" id="spinnerContainer"><div class="spinner-layer style-scope paper-spinner-lite"><div class="circle-clipper left style-scope paper-spinner-lite"><div class="circle style-scope paper-spinner-lite"></div></div><div class="circle-clipper right style-scope paper-spinner-lite"><div class="circle style-scope paper-spinner-lite"></div></div></div></div></paper-spinner-lite>
# </div>
# <div class="style-scope ytd-item-section-renderer" id="contents"><ytd-promoted-sparkles-text-search-renderer class="style-scope ytd-item-section-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="root-container">
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="main-container">
# <h3 class="style-scope ytd-promoted-sparkles-text-search-renderer yt-simple-endpoint" id="title" title="Data Science Associate Degree - 8 &amp; 16 Week Courses">
#             Data Science Associate Degree - 8 &amp; 16 Week Courses
#         </h3>
# <yt-formatted-string class="style-scope ytd-promoted-sparkles-text-search-renderer yt-simple-endpoint" ellipsis-truncate="" id="description" title="Fulfill your passion for data science while learning from expert practitioners. APU offers 200+ online degrees and certificates- both undergraduate and graduate programs. Affordable Tuition. Monthly Starts. Flexible Schedule. Types: Associate, Bachelor's, Master's, Certificates.">Fulfill your passion for data science while learning from expert practitioners. APU offers 200+ online degrees and certificates- both undergraduate and graduate programs. Affordable Tuition. Monthly Starts. Flexible Schedule. Types: Associate, Bachelor's, Master's, Certificates.</yt-formatted-string>
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="format-container">
# <ytd-badge-supported-renderer class="style-scope ytd-promoted-sparkles-text-search-renderer yt-simple-endpoint" id="ad-badge"><!--css-build:shady-->
# <div class="badge badge-style-type-ad style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer" disable-upgrade="" hidden="">
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer">Ad</span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# <yt-formatted-string class="style-scope ytd-promoted-sparkles-text-search-renderer complex-string yt-simple-endpoint" ellipsis-truncate="" id="display-url" title="start.apu.apus.edu/data-science"><span class="style-scope yt-formatted-string" dir="auto" style="color: rgb(6, 95, 212);">start.apu.apus.edu/data-science</span></yt-formatted-string>
# </div>
# </div>
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="right-container">
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-promoted-sparkles-text-search-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><!--css-build:shady--><button aria-label="Action menu" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div>
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="call-to-action"><ytd-button-renderer button-renderer="" class="style-scope ytd-promoted-sparkles-text-search-renderer style-suggestive" is-paper-button="" is-paper-button-with-icon="" use-keyboard-focused=""><a class="yt-simple-endpoint style-scope ytd-button-renderer" href="https://www.google.com/aclk?sa=l&amp;ai=DChcSEwj2jsWMzr7qAhWKnrMKHT8WCHwYABAAGgJxbg&amp;sig=AOD64_3JXRcqafn2gVOQQSYACkKzDA5cPw&amp;adurl=&amp;ms=[CLICK_MS]&amp;nx=[NX]&amp;ny=[NY]&amp;nb=[NB]" tabindex="-1"><paper-button animated="" aria-disabled="false" aria-label="VISIT SITE" class="style-scope ytd-button-renderer style-suggestive" elevation="0" id="button" role="button" tabindex="0"><!--css-build:shady--><yt-formatted-string class="style-scope ytd-button-renderer style-suggestive" id="text">VISIT SITE</yt-formatted-string><yt-icon class="style-scope ytd-button-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 48 48"><g class="style-scope yt-icon" viewbox="0 0 48 48">
# <path class="style-scope yt-icon" d="M38 38H10V10h14V6H10c-2.21 0-4 1.79-4 4v28c0 2.21 1.79 4 4 4h28c2.21 0 4-1.79 4-4V24h-4v14zM28 6v4h7.17L15.51 29.66l2.83 2.83L38 12.83V20h4V6H28z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon></paper-button></a></ytd-button-renderer></div>
# </div>
# </div>
# </ytd-promoted-sparkles-text-search-renderer></div>
# <div class="style-scope ytd-item-section-renderer" id="continuations"></div>
# </ytd-item-section-renderer><ytd-item-section-renderer class="style-scope ytd-section-list-renderer" use-height-hack=""><!--css-build:shady-->
# <div class="style-scope ytd-item-section-renderer" id="header"></div>
# <div class="style-scope ytd-item-section-renderer" id="spinner-container">
# <paper-spinner-lite aria-hidden="true" class="style-scope ytd-item-section-renderer"><!--css-build:shady--><div class="style-scope paper-spinner-lite" id="spinnerContainer"><div class="spinner-layer style-scope paper-spinner-lite"><div class="circle-clipper left style-scope paper-spinner-lite"><div class="circle style-scope paper-spinner-lite"></div></div><div class="circle-clipper right style-scope paper-spinner-lite"><div class="circle style-scope paper-spinner-lite"></div></div></div></div></paper-spinner-lite>
# </div>
# <div class="style-scope ytd-item-section-renderer" id="contents"><ytd-promoted-sparkles-text-search-renderer class="style-scope ytd-item-section-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="root-container">
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="main-container">
# <h3 class="style-scope ytd-promoted-sparkles-text-search-renderer yt-simple-endpoint" id="title" title="Data Science Online Course - Work on 15+ Real-Life Projects">
#             Data Science Online Course - Work on 15+ Real-Life Projects
#         </h3>
# <yt-formatted-string class="style-scope ytd-promoted-sparkles-text-search-renderer yt-simple-endpoint" ellipsis-truncate="" id="description" title="15+ Real-life Projects using Machine Learning, Python &amp; Hadoop. Learn Online from Experts. 30+ In-Demand Skills &amp; Tools, Access to 150+ instructor-led online classes for a year. 24x7 Support. 1 Mn+ Learners Trained. Learn from Home. Data Science Capstone. 15+ Real-World Projects. Courses: Data Scientist Course, Data Science with Python, Machine Learning, Big Data Hadoop.">15+ Real-life Projects using Machine Learning, Python &amp; Hadoop. Learn Online from Experts. 30+ In-Demand Skills &amp; Tools, Access to 150+ instructor-led online classes for a year. 24x7 Support. 1 Mn+ Learners Trained. Learn from Home. Data Science Capstone. 15+ Real-World Projects. Courses: Data Scientist Course, Data Science with Python, Machine Learning, Big Data Hadoop.</yt-formatted-string>
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="format-container">
# <ytd-badge-supported-renderer class="style-scope ytd-promoted-sparkles-text-search-renderer yt-simple-endpoint" id="ad-badge"><!--css-build:shady-->
# <div class="badge badge-style-type-ad style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer" disable-upgrade="" hidden="">
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer">Ad</span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# <yt-formatted-string class="style-scope ytd-promoted-sparkles-text-search-renderer complex-string yt-simple-endpoint" ellipsis-truncate="" id="display-url" title="www.simplilearn.com/data/scientist"><span class="style-scope yt-formatted-string" dir="auto" style="color: rgb(6, 95, 212);">www.simplilearn.com/data/scientist</span></yt-formatted-string>
# </div>
# </div>
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="right-container">
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-promoted-sparkles-text-search-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><!--css-build:shady--><button aria-label="Action menu" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div>
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="call-to-action"><ytd-button-renderer button-renderer="" class="style-scope ytd-promoted-sparkles-text-search-renderer style-suggestive" is-paper-button="" is-paper-button-with-icon="" use-keyboard-focused=""><a class="yt-simple-endpoint style-scope ytd-button-renderer" href="https://www.google.com/aclk?sa=l&amp;ai=DChcSEwj2jsWMzr7qAhWKnrMKHT8WCHwYABACGgJxbg&amp;sig=AOD64_1qL4bA6ae3Q8CSAHFxhNg4KEbUWw&amp;adurl=&amp;ms=[CLICK_MS]&amp;nx=[NX]&amp;ny=[NY]&amp;nb=[NB]" tabindex="-1"><paper-button animated="" aria-disabled="false" aria-label="VISIT SITE" class="style-scope ytd-button-renderer style-suggestive" elevation="0" id="button" role="button" tabindex="0"><!--css-build:shady--><yt-formatted-string class="style-scope ytd-button-renderer style-suggestive" id="text">VISIT SITE</yt-formatted-string><yt-icon class="style-scope ytd-button-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 48 48"><g class="style-scope yt-icon" viewbox="0 0 48 48">
# <path class="style-scope yt-icon" d="M38 38H10V10h14V6H10c-2.21 0-4 1.79-4 4v28c0 2.21 1.79 4 4 4h28c2.21 0 4-1.79 4-4V24h-4v14zM28 6v4h7.17L15.51 29.66l2.83 2.83L38 12.83V20h4V6H28z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon></paper-button></a></ytd-button-renderer></div>
# </div>
# </div>
# </ytd-promoted-sparkles-text-search-renderer></div>
# <div class="style-scope ytd-item-section-renderer" id="continuations"></div>
# </ytd-item-section-renderer><ytd-item-section-renderer class="style-scope ytd-section-list-renderer" use-height-hack=""><!--css-build:shady-->
# <div class="style-scope ytd-item-section-renderer" id="header"></div>
# <div class="style-scope ytd-item-section-renderer" id="spinner-container">
# <paper-spinner-lite aria-hidden="true" class="style-scope ytd-item-section-renderer"><!--css-build:shady--><div class="style-scope paper-spinner-lite" id="spinnerContainer"><div class="spinner-layer style-scope paper-spinner-lite"><div class="circle-clipper left style-scope paper-spinner-lite"><div class="circle style-scope paper-spinner-lite"></div></div><div class="circle-clipper right style-scope paper-spinner-lite"><div class="circle style-scope paper-spinner-lite"></div></div></div></div></paper-spinner-lite>
# </div>
# <div class="style-scope ytd-item-section-renderer" id="contents"><ytd-promoted-sparkles-text-search-renderer class="style-scope ytd-item-section-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="root-container">
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="main-container">
# <h3 class="style-scope ytd-promoted-sparkles-text-search-renderer yt-simple-endpoint" id="title" title="Become a Data Scientist - 12-Week Data Science Bootcamp">
#             Become a Data Scientist - 12-Week Data Science Bootcamp
#         </h3>
# <yt-formatted-string class="style-scope ytd-promoted-sparkles-text-search-renderer yt-simple-endpoint" ellipsis-truncate="" id="description" title="Learn data science by doing real-world projects and build your data science portfolio. Master industry-used tools w/ R, Python, Machine Learning, Big Data, and Deep Learning. Real-world applications. Learn Python &amp; R. Extensive Curriculum. No Application Fee. Schedule an Info Call.">Learn data science by doing real-world projects and build your data science portfolio. Master industry-used tools w/ R, Python, Machine Learning, Big Data, and Deep Learning. Real-world applications. Learn Python &amp; R. Extensive Curriculum. No Application Fee. Schedule an Info Call.</yt-formatted-string>
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="format-container">
# <ytd-badge-supported-renderer class="style-scope ytd-promoted-sparkles-text-search-renderer yt-simple-endpoint" id="ad-badge"><!--css-build:shady-->
# <div class="badge badge-style-type-ad style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer" disable-upgrade="" hidden="">
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer">Ad</span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# <yt-formatted-string class="style-scope ytd-promoted-sparkles-text-search-renderer complex-string yt-simple-endpoint" ellipsis-truncate="" id="display-url" title="info.nycdatascience.com/data_science/bootcamp"><span class="style-scope yt-formatted-string" dir="auto" style="color: rgb(6, 95, 212);">info.nycdatascience.com/data_science/bootcamp</span></yt-formatted-string>
# </div>
# </div>
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="right-container">
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-promoted-sparkles-text-search-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><!--css-build:shady--><button aria-label="Action menu" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div>
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="call-to-action"><ytd-button-renderer button-renderer="" class="style-scope ytd-promoted-sparkles-text-search-renderer style-suggestive" is-paper-button="" is-paper-button-with-icon="" use-keyboard-focused=""><a class="yt-simple-endpoint style-scope ytd-button-renderer" href="https://www.google.com/aclk?sa=l&amp;ai=DChcSEwj2jsWMzr7qAhWKnrMKHT8WCHwYABABGgJxbg&amp;sig=AOD64_3LBbYrS6J5faJxhMglwcPGBc6x-w&amp;adurl=&amp;ms=[CLICK_MS]&amp;nx=[NX]&amp;ny=[NY]&amp;nb=[NB]" tabindex="-1"><paper-button animated="" aria-disabled="false" aria-label="VISIT SITE" class="style-scope ytd-button-renderer style-suggestive" elevation="0" id="button" role="button" tabindex="0"><!--css-build:shady--><yt-formatted-string class="style-scope ytd-button-renderer style-suggestive" id="text">VISIT SITE</yt-formatted-string><yt-icon class="style-scope ytd-button-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 48 48"><g class="style-scope yt-icon" viewbox="0 0 48 48">
# <path class="style-scope yt-icon" d="M38 38H10V10h14V6H10c-2.21 0-4 1.79-4 4v28c0 2.21 1.79 4 4 4h28c2.21 0 4-1.79 4-4V24h-4v14zM28 6v4h7.17L15.51 29.66l2.83 2.83L38 12.83V20h4V6H28z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon></paper-button></a></ytd-button-renderer></div>
# </div>
# </div>
# </ytd-promoted-sparkles-text-search-renderer></div>
# <div class="style-scope ytd-item-section-renderer" id="continuations"></div>
# </ytd-item-section-renderer><ytd-item-section-renderer class="style-scope ytd-section-list-renderer" use-height-hack=""><!--css-build:shady-->
# <div class="style-scope ytd-item-section-renderer" id="header"></div>
# <div class="style-scope ytd-item-section-renderer" id="spinner-container">
# <paper-spinner-lite aria-hidden="true" class="style-scope ytd-item-section-renderer"><!--css-build:shady--><div class="style-scope paper-spinner-lite" id="spinnerContainer"><div class="spinner-layer style-scope paper-spinner-lite"><div class="circle-clipper left style-scope paper-spinner-lite"><div class="circle style-scope paper-spinner-lite"></div></div><div class="circle-clipper right style-scope paper-spinner-lite"><div class="circle style-scope paper-spinner-lite"></div></div></div></div></paper-spinner-lite>
# </div>
# <div class="style-scope ytd-item-section-renderer" id="contents"><ytd-video-renderer class="style-scope ytd-item-section-renderer" lockup="" prominent-thumb-style="DEFAULT"><!--css-build:shady-->
# <div class="style-scope ytd-video-renderer" id="dismissable">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property=""><!--css-build:shady-->
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=xC-c7E5PK0Y" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/xC-c7E5PK0Y/hqdefault.jpg?sqp=-oaymwEZCNACELwBSFXyq4qpAwsIARUAAIhCGAFwAQ==&amp;rs=AOn4CLBhWlGQwMqD-jxTV6j5NTBqyOP0GA" width="246"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="11 minutes, 9 seconds" class="style-scope ytd-thumbnail-overlay-time-status-renderer">
#       11:09
#     </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady-->
# <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">Now playing</span>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="What REALLY is Data Science? Told by a Data Scientist by Joma Tech 2 years ago 11 minutes, 9 seconds 1,440,097 views" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=xC-c7E5PK0Y" id="video-title" title="What REALLY is Data Science? Told by a Data Scientist">
# <yt-formatted-string aria-label="What REALLY is Data Science? Told by a Data Scientist by Joma Tech 2 years ago 11 minutes, 9 seconds 1,440,097 views" class="style-scope ytd-video-renderer">What REALLY is Data Science? Told by a Data Scientist</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><!--css-build:shady--><button aria-label="Action menu" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UCV0qA-eDDICsRR9rPcnG7tw" spellcheck="false">Joma Tech</a></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#
#         Joma Tech
#
#     </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name"><!--css-build:shady-->
# <div class="badge badge-style-type-verified style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" clip-rule="evenodd" d="M12,2C6.48,2,2,6.48,2,12s4.48,10,10,10s10-4.48,10-10 S17.52,2,12,2z M9.92,17.93l-4.95-4.95l2.05-2.05l2.9,2.9l7.35-7.35l2.05,2.05L9.92,17.93z" fill-rule="evenodd"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer"></span>
# <paper-tooltip class="style-scope ytd-badge-supported-renderer" position="top" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#       Verified
#     </div>
# </paper-tooltip></div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">1.4M views</span>
# <span class="style-scope ytd-video-meta-block">2 years ago</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <div class="style-scope ytd-video-renderer" hidden="" id="channel-info">
# <a aria-label="Go to channel" class="style-scope ytd-video-renderer" href="/channel/UCV0qA-eDDICsRR9rPcnG7tw">
# <yt-img-shadow class="style-scope ytd-video-renderer no-transition empty" style="background-color: transparent;" width="24"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" width="24"/></yt-img-shadow>
# </a>
# <ytd-channel-name class="long-byline style-scope ytd-video-renderer" id="channel-name" wrap-text="true"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UCV0qA-eDDICsRR9rPcnG7tw" spellcheck="false">Joma Tech</a></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#
#         Joma Tech
#
#     </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name"><!--css-build:shady-->
# <div class="badge badge-style-type-verified style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" clip-rule="evenodd" d="M12,2C6.48,2,2,6.48,2,12s4.48,10,10,10s10-4.48,10-10 S17.52,2,12,2z M9.92,17.93l-4.95-4.95l2.05-2.05l2.9,2.9l7.35-7.35l2.05,2.05L9.92,17.93z" fill-rule="evenodd"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer"></span>
# <paper-tooltip class="style-scope ytd-badge-supported-renderer" position="top" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#       Verified
#     </div>
# </paper-tooltip></div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" id="description-text">► Resume Template and Cover letter I used for applying to software internships and full-time jobs:
# https://resume.joma.io ...</yt-formatted-string>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" id="badges"><!--css-build:shady-->
# <div class="badge badge-style-type-simple style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer" disable-upgrade="" hidden="">
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer">CC</span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# </ytd-video-renderer><ytd-video-renderer class="style-scope ytd-item-section-renderer" lockup="" prominent-thumb-style="DEFAULT"><!--css-build:shady-->
# <div class="style-scope ytd-video-renderer" id="dismissable">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property=""><!--css-build:shady-->
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=ua-CiDNNj30" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/ua-CiDNNj30/hqdefault.jpg?sqp=-oaymwEZCNACELwBSFXyq4qpAwsIARUAAIhCGAFwAQ==&amp;rs=AOn4CLBpVXLMYajOiEnyf5vE9A12mRkN5w" width="246"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="5 hours, 52 minutes, 9 seconds" class="style-scope ytd-thumbnail-overlay-time-status-renderer">
#       5:52:09
#     </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady-->
# <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">Now playing</span>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="Learn Data Science Tutorial - Full Course for Beginners by freeCodeCamp.org 1 year ago 5 hours, 52 minutes 839,476 views" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=ua-CiDNNj30" id="video-title" title="Learn Data Science Tutorial - Full Course for Beginners">
# <yt-formatted-string aria-label="Learn Data Science Tutorial - Full Course for Beginners by freeCodeCamp.org 1 year ago 5 hours, 52 minutes 839,476 views" class="style-scope ytd-video-renderer">Learn Data Science Tutorial - Full Course for Beginners</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><!--css-build:shady--><button aria-label="Action menu" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UC8butISFwT-Wl7EV0hUK0BQ" spellcheck="false">freeCodeCamp.org</a></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#
#         freeCodeCamp.org
#
#     </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name"><!--css-build:shady-->
# <div class="badge badge-style-type-verified style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" clip-rule="evenodd" d="M12,2C6.48,2,2,6.48,2,12s4.48,10,10,10s10-4.48,10-10 S17.52,2,12,2z M9.92,17.93l-4.95-4.95l2.05-2.05l2.9,2.9l7.35-7.35l2.05,2.05L9.92,17.93z" fill-rule="evenodd"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer"></span>
# <paper-tooltip class="style-scope ytd-badge-supported-renderer" position="top" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#       Verified
#     </div>
# </paper-tooltip></div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">839K views</span>
# <span class="style-scope ytd-video-meta-block">1 year ago</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <div class="style-scope ytd-video-renderer" hidden="" id="channel-info">
# <a aria-label="Go to channel" class="style-scope ytd-video-renderer" href="/channel/UC8butISFwT-Wl7EV0hUK0BQ">
# <yt-img-shadow class="style-scope ytd-video-renderer no-transition empty" style="background-color: transparent;" width="24"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" width="24"/></yt-img-shadow>
# </a>
# <ytd-channel-name class="long-byline style-scope ytd-video-renderer" id="channel-name" wrap-text="true"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UC8butISFwT-Wl7EV0hUK0BQ" spellcheck="false">freeCodeCamp.org</a></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#
#         freeCodeCamp.org
#
#     </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name"><!--css-build:shady-->
# <div class="badge badge-style-type-verified style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" clip-rule="evenodd" d="M12,2C6.48,2,2,6.48,2,12s4.48,10,10,10s10-4.48,10-10 S17.52,2,12,2z M9.92,17.93l-4.95-4.95l2.05-2.05l2.9,2.9l7.35-7.35l2.05,2.05L9.92,17.93z" fill-rule="evenodd"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer"></span>
# <paper-tooltip class="style-scope ytd-badge-supported-renderer" position="top" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#       Verified
#     </div>
# </paper-tooltip></div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" id="description-text"><span class="style-scope yt-formatted-string" dir="auto">Learn </span><span class="bold style-scope yt-formatted-string" dir="auto">Data Science</span><span class="style-scope yt-formatted-string" dir="auto"> is this full tutorial course for absolute beginners. </span><span class="bold style-scope yt-formatted-string" dir="auto">Data science</span><span class="style-scope yt-formatted-string" dir="auto"> is considered the "sexiest job of the 21st ...</span></yt-formatted-string>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" id="badges"><!--css-build:shady-->
# <div class="badge badge-style-type-simple style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer" disable-upgrade="" hidden="">
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer">CC</span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# </ytd-video-renderer><ytd-video-renderer class="style-scope ytd-item-section-renderer" lockup="" prominent-thumb-style="DEFAULT"><!--css-build:shady-->
# <div class="style-scope ytd-video-renderer" id="dismissable">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property=""><!--css-build:shady-->
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=abSZrmmZTyE" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/abSZrmmZTyE/hqdefault.jpg?sqp=-oaymwEZCNACELwBSFXyq4qpAwsIARUAAIhCGAFwAQ==&amp;rs=AOn4CLCOQw6gmryTUDkB31Lk5sStUdtXWA" width="246"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="19 minutes, 20 seconds" class="style-scope ytd-thumbnail-overlay-time-status-renderer">
#       19:20
#     </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady-->
# <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">Now playing</span>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="Data Science Training Videos 1 DataScience Tutorial for beginners Must Watch +91 8886552866 by Salesforce CRM Training 1 week ago 19 minutes 587 views" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=abSZrmmZTyE" id="video-title" title="Data Science Training Videos 1 DataScience Tutorial for beginners Must Watch +91 8886552866">
# <yt-formatted-string aria-label="Data Science Training Videos 1 DataScience Tutorial for beginners Must Watch +91 8886552866 by Salesforce CRM Training 1 week ago 19 minutes 587 views" class="style-scope ytd-video-renderer">Data Science Training Videos 1 DataScience Tutorial for beginners Must Watch +91 8886552866</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><!--css-build:shady--><button aria-label="Action menu" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer byline-separated"><!--css-build:shady-->
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UCApNLZA8C49Lgba_bl4QH9w" spellcheck="false">Salesforce CRM Training</a></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#
#         Salesforce CRM Training
#
#     </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">587 views</span>
# <span class="style-scope ytd-video-meta-block">1 week ago</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <div class="style-scope ytd-video-renderer" hidden="" id="channel-info">
# <a aria-label="Go to channel" class="style-scope ytd-video-renderer" href="/channel/UCApNLZA8C49Lgba_bl4QH9w">
# <yt-img-shadow class="style-scope ytd-video-renderer no-transition empty" style="background-color: transparent;" width="24"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" width="24"/></yt-img-shadow>
# </a>
# <ytd-channel-name class="long-byline style-scope ytd-video-renderer" id="channel-name" wrap-text="true"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UCApNLZA8C49Lgba_bl4QH9w" spellcheck="false">Salesforce CRM Training</a></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#
#         Salesforce CRM Training
#
#     </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" id="description-text">Data science data science training data science tutorial data science videos datascience course data science jobs data science ...</yt-formatted-string>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" id="badges"><!--css-build:shady-->
# <div class="badge badge-style-type-simple style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer" disable-upgrade="" hidden="">
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer">CC</span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# </ytd-video-renderer><ytd-video-renderer class="style-scope ytd-item-section-renderer" lockup="" prominent-thumb-style="DEFAULT"><!--css-build:shady-->
# <div class="style-scope ytd-video-renderer" id="dismissable">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property=""><!--css-build:shady-->
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=X3paOmcrTjQ" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition empty" ftl-eligible="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" width="246"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="4 minutes, 38 seconds" class="style-scope ytd-thumbnail-overlay-time-status-renderer">
#       4:38
#     </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady-->
# <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">Now playing</span>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# ...
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><!--css-build:shady--><button aria-label="Action menu" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/user/TEDxTalks" spellcheck="false">TEDx Talks</a></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#
#         TEDx Talks
#
#     </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name"><!--css-build:shady-->
# <div class="badge badge-style-type-verified style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" clip-rule="evenodd" d="M12,2C6.48,2,2,6.48,2,12s4.48,10,10,10s10-4.48,10-10 S17.52,2,12,2z M9.92,17.93l-4.95-4.95l2.05-2.05l2.9,2.9l7.35-7.35l2.05,2.05L9.92,17.93z" fill-rule="evenodd"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer"></span>
# <paper-tooltip class="style-scope ytd-badge-supported-renderer" position="top" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#       Verified
#     </div>
# </paper-tooltip></div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">169K views</span>
# <span class="style-scope ytd-video-meta-block">2 years ago</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <div class="style-scope ytd-video-renderer" hidden="" id="channel-info">
# <a aria-label="Go to channel" class="style-scope ytd-video-renderer" href="/user/TEDxTalks">
# <yt-img-shadow class="style-scope ytd-video-renderer no-transition empty" style="background-color: transparent;" width="24"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" width="24"/></yt-img-shadow>
# </a>
# <ytd-channel-name class="long-byline style-scope ytd-video-renderer" id="channel-name" wrap-text="true"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/user/TEDxTalks" spellcheck="false">TEDx Talks</a></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#
#         TEDx Talks
#
#     </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name"><!--css-build:shady-->
# <div class="badge badge-style-type-verified style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" clip-rule="evenodd" d="M12,2C6.48,2,2,6.48,2,12s4.48,10,10,10s10-4.48,10-10 S17.52,2,12,2z M9.92,17.93l-4.95-4.95l2.05-2.05l2.9,2.9l7.35-7.35l2.05,2.05L9.92,17.93z" fill-rule="evenodd"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer"></span>
# <paper-tooltip class="style-scope ytd-badge-supported-renderer" position="top" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#       Verified
#     </div>
# </paper-tooltip></div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" id="description-text"><span class="style-scope yt-formatted-string" dir="auto">How big </span><span class="bold style-scope yt-formatted-string" dir="auto">data</span><span class="style-scope yt-formatted-string" dir="auto"> starts to drive the world, and what kind of skills will you need to interpret it? General Director of Alto </span><span class="bold style-scope yt-formatted-string" dir="auto">Data</span><span class="style-scope yt-formatted-string" dir="auto"> Analytics, ...</span></yt-formatted-string>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="" id="badges">
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# </ytd-video-renderer><ytd-video-renderer class="style-scope ytd-item-section-renderer" lockup="" prominent-thumb-style="DEFAULT"><!--css-build:shady-->
# <div class="style-scope ytd-video-renderer" id="dismissable">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property=""><!--css-build:shady-->
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=sdBWA9MvgYI" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition empty" ftl-eligible="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" width="246"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="11 minutes, 43 seconds" class="style-scope ytd-thumbnail-overlay-time-status-renderer">
#       11:43
#     </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady-->
# <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">Now playing</span>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="The Facebook Data Science Interview Questions by Data Science Jay 3 months ago 11 minutes, 43 seconds 4,100 views" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=sdBWA9MvgYI" id="video-title" title="The Facebook Data Science Interview Questions">
# <yt-formatted-string aria-label="The Facebook Data Science Interview Questions by Data Science Jay 3 months ago 11 minutes, 43 seconds 4,100 views" class="style-scope ytd-video-renderer">The Facebook Data Science Interview Questions</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><!--css-build:shady--><button aria-label="Action menu" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer byline-separated"><!--css-build:shady-->
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UCcQx1UnmorvmSEZef4X7-6g" spellcheck="false">Data Science Jay</a></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#
#         Data Science Jay
#
#     </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">4.1K views</span>
# <span class="style-scope ytd-video-meta-block">3 months ago</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <div class="style-scope ytd-video-renderer" hidden="" id="channel-info">
# <a aria-label="Go to channel" class="style-scope ytd-video-renderer" href="/channel/UCcQx1UnmorvmSEZef4X7-6g">
# <yt-img-shadow class="style-scope ytd-video-renderer no-transition empty" style="background-color: transparent;" width="24"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" width="24"/></yt-img-shadow>
# </a>
# <ytd-channel-name class="long-byline style-scope ytd-video-renderer" id="channel-name" wrap-text="true"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UCcQx1UnmorvmSEZef4X7-6g" spellcheck="false">Data Science Jay</a></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#
#         Data Science Jay
#
#     </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" id="description-text"><span class="style-scope yt-formatted-string" dir="auto">The Facebook </span><span class="bold style-scope yt-formatted-string" dir="auto">data scientist</span><span class="style-scope yt-formatted-string" dir="auto"> job role is one of the most coveted positions in tech. Subscribe to our channel: ...</span></yt-formatted-string>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="" id="badges">
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# </ytd-video-renderer></div>
# <div class="style-scope ytd-item-section-renderer" id="continuations"><yt-next-continuation class="style-scope ytd-item-section-renderer"><!--css-build:shady-->
# <paper-spinner aria-hidden="true" class="style-scope yt-next-continuation" id="spinner"><!--css-build:shady--><div class="style-scope paper-spinner" id="spinnerContainer"><div class="spinner-layer layer-1 style-scope paper-spinner"><div class="circle-clipper left style-scope paper-spinner"><div class="circle style-scope paper-spinner"></div></div><div class="circle-clipper right style-scope paper-spinner"><div class="circle style-scope paper-spinner"></div></div></div><div class="spinner-layer layer-2 style-scope paper-spinner"><div class="circle-clipper left style-scope paper-spinner"><div class="circle style-scope paper-spinner"></div></div><div class="circle-clipper right style-scope paper-spinner"><div class="circle style-scope paper-spinner"></div></div></div><div class="spinner-layer layer-3 style-scope paper-spinner"><div class="circle-clipper left style-scope paper-spinner"><div class="circle style-scope paper-spinner"></div></div><div class="circle-clipper right style-scope paper-spinner"><div class="circle style-scope paper-spinner"></div></div></div><div class="spinner-layer layer-4 style-scope paper-spinner"><div class="circle-clipper left style-scope paper-spinner"><div class="circle style-scope paper-spinner"></div></div><div class="circle-clipper right style-scope paper-spinner"><div class="circle style-scope paper-spinner"></div></div></div></div></paper-spinner>
# <dom-if class="style-scope yt-next-continuation"><template is="dom-if"></template></dom-if>
# <dom-if class="style-scope yt-next-continuation"><template is="dom-if"></template></dom-if>
# </yt-next-continuation></div>
# </ytd-item-section-renderer></div>

# %%
contents_div = soup.find('div', id='contents')

for title in contents_div.find_all('a', id='video-title'):
    print(title.text.strip())
# Out:
# What REALLY is Data Science? Told by a Data Scientist
# Data Science Training Videos 1 DataScience Tutorial for beginners Must Watch +91 8886552866
# Learn Data Science Tutorial - Full Course for Beginners
# How I Would Learn Data Science (If I Had to Start Over)
# Data Science In 5 Minutes | Data Science For Beginners | What Is Data Science? | Simplilearn
# Data Science Full Course - Learn Data Science in 10 Hours | Data Science For Beginners | Edureka
# 3 Reasons You Should NOT Become a Data Scientist
# Is Data Science Really a Rising Career in 2020 ($100,000+ Salary)
# Demystifying Data Science | Mr.Asitang Mishra | TEDxOakLawn
# Intro to Data Science - Crash Course for Beginners
# A Day In The Life Of A Data Scientist
# Learn Python - Full Course for Beginners [Tutorial]
# Python Tutorial - Python for Beginners [Full Course]
# Data Analytics for Beginners
# Real Talk with Instagram Data Scientist
# Data Scientists vs Data Engineers: Which one is for you?
# What Do You Need to Become a Data Scientist in 2020?
# Statistics for Data Science | Probability and Statistics | Statistics Tutorial | Ph.D. (Stanford)
# Data Scientist vs Data Analyst: What's the difference? ($120,000 vs $70,000 salary)
# Math Needed for Mastering Data Science

# %% [markdown]
# > **QUESTION**: We only got about 20 video titles -- surely there are more videos about data science.  What do you think is happening?

# %% [markdown]
# ### Interacting with Pages
#
# We can also interact with pages using Selenium.  For example, we can
# - click
# - type in input cells
# - scroll
# - drag and drop, etc.
#
# If we want more data science video titles, we need to scroll down to the bottom of the screen for more videos to populate.

# %%
for i in range(5):
    #Scroll
    driver.execute_script(
        "window.scrollTo(0, document.documentElement.scrollHeight);" #Alternatively, document.body.scrollHeight
    )
    
    #Wait for page to load
    time.sleep(1)

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
contents_div = soup.find('div', id='contents')

len(contents_div.find_all('a', id='video-title'))
# Out:
# 116

# %% [markdown]
# Awesome!  Now we have several more videos to analyze and we could continue scrolling if we wanted even more.
#
# What if we want to perform a new search for machine learning?

# %%
search_box = driver.find_element_by_xpath("//input[@id='search']")

#clear the current search
search_box.clear()

#input new search
search_box.send_keys("machine learning")

#hit enter
search_box.send_keys(Keys.RETURN)  

time.sleep(1)

# %% [markdown]
# And can we filter to short videos (< 4 minutes) only?

# %%
filter_button = driver.find_element_by_xpath(
    '//a[contains(@class, "ytd-toggle-button")]'
)
filter_button.click()

# %%
short_link = driver.find_element_by_xpath(
    '//div[contains(@title, "Search for Short")]'
)
short_link.click()

# %% [markdown]
# Now we can either parse the page source with Beautiful Soup like before or pull text directly.
#
# For example, the title of the first short ML video (that isn't an ad!) can be found with:

# %%
first_title = driver.find_element_by_xpath("//a[@id='video-title']")
first_title.text
# Out:
# 'What is Machine Learning?'

# %%
first_author = driver.find_element_by_xpath(
    "//ytd-video-renderer//ytd-channel-name//a"
)
first_author.text
# Out:
# 'OxfordSparks'

# %% [markdown]
# #### Notes
#
# - Check [here](https://www.w3schools.com/xml/xpath_syntax.asp) for additonal help writing xpath selectors.
#
# - To select multiple elements, just switch to `driver.find_elements_by_xpath(...)`, which will return a list of matching elements.
#
# - You can also access elements by id, name, etc.  Check [the docs](https://selenium-python.readthedocs.io/locating-elements.html) for more options.

# %% [markdown]
# Finally, when you are finished with the driver, be sure to close it.

# %%
driver.close()

# %% [markdown]
# ## Example 2 - Open Table  _(Optional)_
#
# Let's try one more example: gathering information from Open Table about restaurants with available reservation slots.

# %%
driver = webdriver.Chrome(chromedriver)
driver.get('http://www.opentable.com/')
time.sleep(1)  #pause to be sure page has loaded

# %% [markdown]
# Inspecting this page, we see the **name** of the drop down for picking the number of people is `Select_1`. Let's set the reservation for 4 people:

# %%
people_dropdown = driver.find_element_by_xpath('//select[@aria-label="Party size selector"]')
people_dropdown.send_keys("4 people")
time.sleep(1)

# %% [markdown]
# Now select the reservation date: 3 days from now.

# %%
from datetime import datetime, timedelta

# %%
today = datetime.today()
today_truncated = datetime(today.year, today.month, today.day)
res_date = (today + timedelta(days=3)).strftime('%a, %b %d, %Y')
res_date
# Out:
# 'Sat, Apr 18, 2020'

# %%
#Expand the calendar
date_picker = driver.find_element_by_xpath('//div[@aria-label="Date selector"]')
date_picker.click()
time.sleep(1)

# %%
#Select the date three days from now
date_element = driver.find_element_by_xpath(f'//div[@aria-label="{res_date}"]')
date_element.click()
time.sleep(1)

# %% [markdown]
# Set our reservation time for 8 PM.

# %%
time_dropdown = driver.find_element_by_xpath('//select[@aria-label="Time selector"]')
time_dropdown.send_keys("8:00 PM")
time.sleep(1)

# %% [markdown]
# And search!

# %%
search_button = driver.find_element_by_xpath("//*[contains(text(), 'Let’s go')]")
search_button.click()
time.sleep(1)

# %% [markdown]
# On this new page we find a long list of restaurants with available reservations for 4 people at roughly our desired day/time.  At this point we could grab the HTML (`driver.page_source`) and parse with BeautifulSoup.

# %%
soup = BeautifulSoup(driver.page_source)

# %%
for rest in soup.find_all('div', class_='rest-row-header')[:20]:
    print(rest.find('a').text)
# Out:
# Fratelli's Trattoria  Late Night Find
# 3 Westerly Bar and Grill  Outdoor Dining
# Brothers Fish & Chips
# Restaurant X & Bully Boy Bar  Great for Brunch
# Aji Limo/Peruvian Cuisine
# Melike Turkish Cuisine  Neighborhood Gem
# Flames Bar and Grill
# The Station Kitchen and Bar  Best Service
# Le Jardin du Roi  Great for Brunch
# Vela Kitchen  Contemporary American
# Crabtree's Kittle House  Notable Wine List
# Mediterraneo Ristorante & Caffe
# RiverMarket Bar & Kitchen  Great for Brunch
# Fin & Brew  Outdoor Dining
# Lexington Square Cafe
# Bistro 146  Neighborhood Gem
# 8 North Broadway
# Guadalajara Mexican Restaurant
# Velo  Notable Wine List
# The Hudson Room  Hot Spot

# %% [markdown]
# Or we could click into an individual restaurant to learn more.

# %%
first_rest = driver.find_element_by_xpath('//div[@class="rest-row-header"]//a')
first_rest.click()

# %%
rest_soup = BeautifulSoup(driver.page_source)

print(rest_soup.title.text)
# Out:
# Restaurant Reservation Availability

# %% [markdown]
# > **QUESTION**:  Why doesn't the title of this page match up with this individual restaurant?

# %%
#Switch windows!
driver.switch_to.window(driver.window_handles[1])

# %%
rest_soup = BeautifulSoup(driver.page_source)

print(rest_soup.title.text)
# Out:
# Fratelli's Trattoria Restaurant - Croton-on-Hudson, NY | OpenTable

# %% [markdown]
# As usual when working with Selenium, make sure to close your browser.  Since we have two windows up, we use `driver.quit()` to close the entire browser session.

# %%
driver.quit()
