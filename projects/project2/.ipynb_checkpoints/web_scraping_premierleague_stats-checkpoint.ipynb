# %%
import pandas as pd
import requests
import re
import numpy as np

url = 'https://fbref.com/robots.txt'
response  = requests.get(url)
print(response.text)
# Out:
# User-agent:*
# # Disallow: /cbb/
# # Disallow: /cfb/
# # Disallow: /olympics/
#
# # Disallow: /awards/
# # Disallow: /blog/
# # Disallow: /boxscores/
# # Disallow: /coaches/
# # Disallow: /draft/
# # Disallow: /executives/
# # Disallow: /friv/
# # Disallow: /hof/
# # Disallow: /leaders/
# # Disallow: /play-index/
# # Disallow: /players/
# # Disallow: /route.cgi
# # Disallow: /schools/
# # Disallow: /search/
# # Disallow: /stadiums/
# # Disallow: /static/
# # Disallow: /teams/
# # Disallow: /years/
#
# Disallow: /feedback/
# Disallow: /linker/
# Disallow: /my/
#
# Disallow: /news/
# Disallow: /en/news/
# Disallow: /pt/news/
# Disallow: /de/news/
# Disallow: /fr/news/
# Disallow: /es/news/
# Disallow: /it/news/
# Disallow: /news/
#
# Disallow: /req/
# Disallow: /short/
# Disallow: /nocdn/
#
#
# User-agent: AhrefsBot
# Disallow: /
#
# User-agent: AhrefsBot/5.0
# Disallow: /
#
#
# ## sitemaps generated by copyit/sitemaps/build_sitemaps.pl
# ##
# Sitemap: https://fbref.com/sitemaps/sitemap.xml

# %%
from bs4 import BeautifulSoup
import requests
import time, os

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

chromedriver = "/Applications/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
manutd_1819 = 'https://fbref.com/en/squads/19538871/2018-2019/Manchester-United'

# %%
page = requests.get(manutd_1819).text
soup = BeautifulSoup(page, 'lxml')

# %%
#standard stats table
player_table = soup.find('table', id='stats_standard_ks_1889')

# %%
player_name = [header for header in player_table.find_all('th', class_='left')]
manutd_players = [name.text for th in player_name for name in th.find_all('a')]

# %%
player_row = [row for row in player_table.find_all('tr')]

# %%
players_stats = {}

for player in player_row[2:]:
    items = player.find_all('td') 
    players_stats[player] = [i.text for i in items]

# %%
players_stats_list = [stats for stats in players_stats.values()]

# %%
manutd_players_stats = {}
manutd_players_stats.update(zip(manutd_players, players_stats_list))

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
manutd_1819 = pd.DataFrame(manutd_players_stats).T
manutd_1819.columns = ['Nation','Pos','Age','MP','Starts','Min','Gls','Ast','PK','PKatt','CrdY','CrdR','P90Gls','P90Ast','P90G+A','P90G-PK','P90G+A-PK','ExpectedxG','ExpectednpxG','ExpectedxA','P90xG','P90xA','P90xG+xA','P90npxG','P90npxG+xA','Matches']

# %%
manutd_1819 = manutd_1819.replace(r'^\s*$', np.nan, regex=True)

# %%
manutd_1819 = manutd_1819.drop(['Nation','PK','PKatt','CrdY','CrdR','P90Gls','P90Ast','P90G+A','P90G-PK','P90G+A-PK','ExpectedxG','ExpectednpxG','ExpectedxA','P90xG','P90xA','P90xG+xA','P90npxG','P90npxG+xA','Matches'], axis=1)

# %%
manutd_1819
# Out:
#                      Pos Age  MP Starts    Min  Gls  Ast
# David de Gea          GK  27  38     38  3,420    0    0
# Paul Pogba            MF  25  35     34  3,006   13    9
# Victor Lindelöf       DF  24  30     29  2,601    1    1
# Luke Shaw             DF  23  29     29  2,591    1    4
# Ashley Young          DF  33  30     28  2,569    2    2
# Nemanja Matić         MF  29  28     28  2,436    1    0
# Marcus Rashford       FW  20  33     26  2,334   10    6
# Chris Smalling        DF  28  24     24  2,127    1    0
# Romelu Lukaku         FW  25  32     22  2,136   12    0
# Jesse Lingard      FW,MF  25  27     19  1,663    4    2
# Anthony Martial       FW  22  27     18  1,621   10    2
# Ander Herrera         MF  28  22     16  1,403    2    3
# Juan Mata          FW,MF  30  22     16  1,289    3    2
# Phil Jones            DF  26  18     15  1,263    0    1
# Fred                  MF  25  17     13  1,041    1    1
# Diogo Dalot        DF,MF  19  16     12  1,013    0    2
# Alexis Sánchez     FW,MF  29  20      9    880    1    3
# Scott McTominay    MF,DF  21  16      9    867    2    0
# Eric Bailly           DF  24  12      8    638    0    0
# Marouane Fellaini     MF  30  14      6    752    0    1
# Andreas Pereira       MF  22  15      6    599    1    1
# Antonio Valencia   DF,MF  32   6      5    466    0    0
# Matteo Darmian        DF  28   6      5    443    0    0
# Marcos Rojo           DF  28   5      2    212    0    0
# Mason Greenwood       FW  16   3      1    117    0    0
# Tahith Chong          FW  18   2      0     38    0    0
# Angel Gomes        MF,FW  17   2      0     27    0    0
# James Garner          MF  17   1      0      1    0    0
# Lee Grant             GK  35   0      0    NaN  NaN  NaN
# Sergio Romero         GK  31   0      0    NaN  NaN  NaN

# %%
#shooting stats table
shooting_table = soup.find('table', id="stats_shooting_ks_1889")

# %%
shooting_table

# %%
shooting_name = [header for header in shooting_table.find_all('th', class_='left')]
shooting_players = [name.text for th in shooting_name for name in th.find_all('a')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-e8836bb4c340> in <module>
# ----> 1 shooting_name = [header for header in shooting_table.find_all('th', class_='left')]
#       2 shooting_players = [name.text for th in shooting_name for name in th.find_all('a')]
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
#passing stats table
passing_table = soup.find('table', id='stats_passing_ks_1889')

# %%
passing_table
