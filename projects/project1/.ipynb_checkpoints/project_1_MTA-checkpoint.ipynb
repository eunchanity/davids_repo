# %% [markdown]
# ```
# Topic:        Project 1
# Subject:      Explore MTA turnstile data
# Date:         07/06/2020
# Name:         David Weon
# Worked with:  Adam Rauckhorst, Dyllan Usher
# ```

# %%
import pandas as pd
csvs = ['http://web.mta.info/developers/data/nyct/turnstile/turnstile_190601.txt',
        'http://web.mta.info/developers/data/nyct/turnstile/turnstile_190608.txt',
        'http://web.mta.info/developers/data/nyct/turnstile/turnstile_190615.txt',
        'http://web.mta.info/developers/data/nyct/turnstile/turnstile_190622.txt',
        'http://web.mta.info/developers/data/nyct/turnstile/turnstile_190525.txt',
        'http://web.mta.info/developers/data/nyct/turnstile/turnstile_190518.txt']
df = pd.concat((pd.read_csv(csv) for csv in csvs))

# %%
df.reset_index(inplace=True)

# %%
df.columns = [column.strip() for column in df.columns]

# %%
df['DATETIME'] = pd.to_datetime(df['DATE'] + ' ' + df['TIME'], format="%m/%d/%Y %H:%M:%S")
df
# Out:
#           index    C/A  UNIT       SCP        STATION LINENAME DIVISION  \
# 0             0   A002  R051  02-00-00          59 ST  NQR456W      BMT
# 1             1   A002  R051  02-00-00          59 ST  NQR456W      BMT
# 2             2   A002  R051  02-00-00          59 ST  NQR456W      BMT
# 3             3   A002  R051  02-00-00          59 ST  NQR456W      BMT
# 4             4   A002  R051  02-00-00          59 ST  NQR456W      BMT
# ...         ...    ...   ...       ...            ...      ...      ...
# 1233256  208676  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 1233257  208677  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 1233258  208678  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 1233259  208679  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 1233260  208680  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
#
#                DATE      TIME     DESC  ENTRIES    EXITS            DATETIME
# 0        05/25/2019  00:00:00  REGULAR  7071830  2396411 2019-05-25 00:00:00
# 1        05/25/2019  04:00:00  REGULAR  7071844  2396415 2019-05-25 04:00:00
# 2        05/25/2019  08:00:00  REGULAR  7071864  2396443 2019-05-25 08:00:00
# 3        05/25/2019  12:00:00  REGULAR  7071943  2396500 2019-05-25 12:00:00
# 4        05/25/2019  16:00:00  REGULAR  7072182  2396555 2019-05-25 16:00:00
# ...             ...       ...      ...      ...      ...                 ...
# 1233256  05/17/2019  01:00:00  REGULAR     5554      376 2019-05-17 01:00:00
# 1233257  05/17/2019  05:00:00  REGULAR     5554      376 2019-05-17 05:00:00
# 1233258  05/17/2019  09:00:00  REGULAR     5554      376 2019-05-17 09:00:00
# 1233259  05/17/2019  17:00:00  REGULAR     5554      376 2019-05-17 17:00:00
# 1233260  05/17/2019  21:00:00  REGULAR     5554      378 2019-05-17 21:00:00
#
# [1233261 rows x 13 columns]

# %%
#checking for duplicates
(df
.groupby(["C/A", "UNIT", "SCP", "STATION", "DATETIME"])
.ENTRIES.count()
.reset_index()
.sort_values("ENTRIES", ascending=False)
.head(20))
# Out:
#           C/A  UNIT       SCP          STATION            DATETIME  ENTRIES
# 870892   R174  R034  00-00-02           125 ST 2019-06-08 00:00:00        2
# 612865   N525  R142  01-00-04   DELANCEY/ESSEX 2019-05-11 05:00:00        2
# 291196   N045  R187  01-00-02     81 ST-MUSEUM 2019-06-01 17:00:00        2
# 291507   N045  R187  01-06-00     81 ST-MUSEUM 2019-06-11 21:00:00        2
# 291201   N045  R187  01-00-02     81 ST-MUSEUM 2019-06-02 17:00:00        2
# 290953   N045  R187  01-00-01     81 ST-MUSEUM 2019-06-02 17:00:00        2
# 177966   G009  R151  02-00-03  CONEY IS-STILLW 2019-05-16 17:00:00        2
# 178219   G009  R151  02-00-04  CONEY IS-STILLW 2019-05-16 17:00:00        2
# 612613   N525  R142  01-00-03   DELANCEY/ESSEX 2019-05-11 05:00:00        2
# 870637   R174  R034  00-00-01           125 ST 2019-06-08 00:00:00        2
# 1016638  R290  R161  00-00-00   KINGSBRIDGE RD 2019-06-07 05:00:00        2
# 291290   N045  R187  01-00-02     81 ST-MUSEUM 2019-06-17 09:00:00        2
# 290948   N045  R187  01-00-01     81 ST-MUSEUM 2019-06-01 17:00:00        2
# 291452   N045  R187  01-06-00     81 ST-MUSEUM 2019-06-02 17:00:00        2
# 290702   N045  R187  01-00-00     81 ST-MUSEUM 2019-06-02 17:00:00        2
# 290697   N045  R187  01-00-00     81 ST-MUSEUM 2019-06-01 17:00:00        2
# 871147   R174  R034  00-00-03           125 ST 2019-06-08 00:00:00        2
# 822182   R142  R293  01-00-02   34 ST-PENN STA 2019-05-19 10:00:00        1
# 822174   R142  R293  01-00-02   34 ST-PENN STA 2019-05-18 02:00:00        1
# 822165   R142  R293  01-00-02   34 ST-PENN STA 2019-05-16 22:00:00        1

# %%
df.sort_values(["C/A", "UNIT", "SCP", "STATION", "DATETIME"], 
                          inplace=True, ascending=False)
df.drop_duplicates(subset=["C/A", "UNIT", "SCP", "STATION", "DATETIME"], inplace=True)

# %%
(df
 .groupby(["C/A", "UNIT", "SCP", "STATION", "DATETIME"])
 .ENTRIES.count()
 .reset_index()
 .sort_values("ENTRIES", ascending=False)).head(5)
# Out:
#          C/A  UNIT       SCP         STATION            DATETIME  ENTRIES
# 0       A002  R051  02-00-00           59 ST 2019-05-11 00:00:00        1
# 822170  R142  R293  01-00-02  34 ST-PENN STA 2019-05-17 10:00:00        1
# 822168  R142  R293  01-00-02  34 ST-PENN STA 2019-05-17 08:58:51        1
# 822167  R142  R293  01-00-02  34 ST-PENN STA 2019-05-17 06:00:00        1
# 822166  R142  R293  01-00-02  34 ST-PENN STA 2019-05-17 02:00:00        1

# %%
df = df.drop(["EXITS", "DESC"], axis=1, errors="ignore")

# %%
turnstiles_daily = (df
                   .groupby(["C/A", "UNIT", "SCP", "STATION", "DATE"],as_index=False)
                   .ENTRIES.first())

# %%
turnstiles_daily[["PREV_DATE", "PREV_ENTRIES"]] = (turnstiles_daily
                                                       .groupby(["C/A", "UNIT", "SCP", "STATION"])["DATE", "ENTRIES"]
                                                       .apply(lambda grp: grp.shift(1)))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
turnstiles_daily.dropna(subset=["PREV_DATE"], axis=0, inplace=True)

# %%
turnstiles_daily[turnstiles_daily["ENTRIES"] < turnstiles_daily["PREV_ENTRIES"]].head()
# Out:
#        C/A  UNIT       SCP          STATION        DATE     ENTRIES  \
# 3231  A025  R023  01-03-01  34 ST-HERALD SQ  05/12/2019  1238416287
# 3232  A025  R023  01-03-01  34 ST-HERALD SQ  05/13/2019  1238412729
# 3233  A025  R023  01-03-01  34 ST-HERALD SQ  05/14/2019  1238408861
# 3234  A025  R023  01-03-01  34 ST-HERALD SQ  05/15/2019  1238404863
# 3235  A025  R023  01-03-01  34 ST-HERALD SQ  05/16/2019  1238400648
#
#        PREV_DATE  PREV_ENTRIES
# 3231  05/11/2019  1.238418e+09
# 3232  05/12/2019  1.238416e+09
# 3233  05/13/2019  1.238413e+09
# 3234  05/14/2019  1.238409e+09
# 3235  05/15/2019  1.238405e+09

# %%
(turnstiles_daily[turnstiles_daily["ENTRIES"] < turnstiles_daily["PREV_ENTRIES"]]
    .groupby(["C/A", "UNIT", "SCP", "STATION"])
    .size())
# Out:
# C/A   UNIT  SCP       STATION
# A025  R023  01-03-01  34 ST-HERALD SQ    41
# A037  R170  05-00-00  14 ST-UNION SQ      1
# A043  R462  00-06-00  CANAL ST            1
# A049  R088  02-05-00  CORTLANDT ST       35
# A066  R118  00-00-00  CANAL ST           41
#                                          ..
# R610  R057  00-04-01  ATL AV-BARCLAY      1
# R621  R060  00-03-01  EASTN PKWY-MUSM     2
# R622  R123  00-00-00  FRANKLIN AV        41
# R646  R110  01-00-01  FLATBUSH AV-B.C    41
# R730  R431  00-00-04  EASTCHSTER/DYRE    41
# Length: 446, dtype: int64

# %%
def get_daily_counts(row, max_counter):
    counter = row["ENTRIES"] - row["PREV_ENTRIES"]
    if counter < 0:
        # Maybe counter is reversed?
        counter = -counter
    if counter > max_counter:
        # Maybe counter was reset to 0? 
        print(row["ENTRIES"], row["PREV_ENTRIES"])
        counter = min(row["ENTRIES"], row["PREV_ENTRIES"])
    if counter > max_counter:
        # Check it again to make sure we're not still giving a counter that's too big
        return 0
    return counter
turnstiles_daily["DAILY_ENTRIES"] = turnstiles_daily.apply(get_daily_counts, axis=1, max_counter
# 48  A002  R051  02-00-01   59 ST  05/17/2019  6290296  05/16/2019
# 49  A002  R051  02-00-01   59 ST  05/18/2019  6291026  05/17/2019
# 50  A002  R051  02-00-01   59 ST  05/19/2019  6291627  05/18/2019
# 51  A002  R051  02-00-01   59 ST  05/20/2019  6292831  05/19/2019
#
#     PREV_ENTRIES  DAILY_ENTRIES
# 1      7054133.0          536.0
# 2      7054669.0         1295.0
# 3      7055964.0         1485.0
# 4      7057449.0         1562.0
# 5      7059011.0         1685.0
# 6      7060696.0         1578.0
# 7      7062274.0          823.0
# 8      7063097.0          761.0
# 9      7063858.0         1423.0
# 10     7065281.0         1589.0
# 11     7066870.0         1611.0
# 12     7068481.0         1613.0
# 13     7070094.0         1530.0
# 14     7071624.0          832.0
# 15     7072456.0          658.0
# 16     7073114.0          723.0
# 17     7073837.0         1423.0
# 18     7075260.0         1529.0
# 19     7076789.0         1484.0
# 20     7078273.0         1589.0
# 21     7079862.0          955.0
# 22     7080817.0          750.0
# 23     7081567.0         1382.0
# 24     7082949.0         1616.0
# 25     7084565.0         1544.0
# 26     7086109.0         1548.0
# 27     7087657.0         1611.0
# 28     7089268.0          847.0
# 29     7090115.0          759.0
# 30     7090874.0         1395.0
# 31     7092269.0         1534.0
# 32     7093803.0         1604.0
# 33     7095407.0         1510.0
# 34     7096917.0         1564.0
# 35     7098481.0          945.0
# 36     7099426.0          662.0
# 37     7100088.0         1399.0
# 38     7101487.0         1437.0
# 39     7102924.0         1575.0
# 40     7104499.0         1478.0
# 41     7105977.0         1531.0
# 43     6283731.0          470.0
# 44     6284201.0         1144.0
# 45     6285345.0         1174.0
# 46     6286519.0         1238.0
# 47     6287757.0         1274.0
# 48     6289031.0         1265.0
# 49     6290296.0          730.0
# 50     6291026.0          601.0
# 51     6291627.0         1204.0

# %%
turnstiles_daily = turnstiles_daily[~mask]

# %%
turnstiles_daily.describe(percentiles = [.97,.98,.99,.991,.992,.997])
# Out:
#             ENTRIES  PREV_ENTRIES  DAILY_ENTRIES
# count  1.983690e+05  1.983690e+05  198369.000000
# mean   4.194951e+07  4.194592e+07    1055.954252
# std    2.133001e+08  2.132985e+08    1016.576936
# min    0.000000e+00  0.000000e+00       0.000000
# 50%    2.137689e+06  2.138338e+06     804.000000
# 97%    3.319995e+08  3.319970e+08    3399.000000
# 98%    7.307730e+08  7.307719e+08    3787.000000
# 99%    1.397500e+09  1.397500e+09    4400.320000
# 99.1%  1.442696e+09  1.442704e+09    4504.688000
# 99.2%  1.556082e+09  1.556087e+09    4610.000000
# 99.7%  1.928604e+09  1.928604e+09    5450.896000
# max    2.129314e+09  2.129315e+09    9978.000000

# %%
import seaborn as sns

sns.distplot(turnstiles_daily.DAILY_ENTRIES)

# %%
mask2 = (turnstiles_daily.DAILY_ENTRIES > 6000)
turnstiles_daily = turnstiles_daily[~mask2]

# %%
turnstiles_daily.DAILY_ENTRIES = turnstiles_daily.DAILY_ENTRIES.astype(int)
turnstiles_daily
# Out:
#           C/A  UNIT       SCP        STATION        DATE  ENTRIES   PREV_DATE  \
# 1        A002  R051  02-00-00          59 ST  05/12/2019  7054669  05/11/2019
# 2        A002  R051  02-00-00          59 ST  05/13/2019  7055964  05/12/2019
# 3        A002  R051  02-00-00          59 ST  05/14/2019  7057449  05/13/2019
# 4        A002  R051  02-00-00          59 ST  05/15/2019  7059011  05/14/2019
# 5        A002  R051  02-00-00          59 ST  05/16/2019  7060696  05/15/2019
# ...       ...   ...       ...            ...         ...      ...         ...
# 203437  TRAM2  R469  00-05-01  RIT-ROOSEVELT  06/17/2019     5554  06/16/2019
# 203438  TRAM2  R469  00-05-01  RIT-ROOSEVELT  06/18/2019     5554  06/17/2019
# 203439  TRAM2  R469  00-05-01  RIT-ROOSEVELT  06/19/2019     5554  06/18/2019
# 203440  TRAM2  R469  00-05-01  RIT-ROOSEVELT  06/20/2019     5554  06/19/2019
# 203441  TRAM2  R469  00-05-01  RIT-ROOSEVELT  06/21/2019     5554  06/20/2019
#
#         PREV_ENTRIES  DAILY_ENTRIES
# 1          7054133.0            536
# 2          7054669.0           1295
# 3          7055964.0           1485
# 4          7057449.0           1562
# 5          7059011.0           1685
# ...              ...            ...
# 203437        5554.0              0
# 203438        5554.0              0
# 203439        5554.0              0
# 203440        5554.0              0
# 203441        5554.0              0
#
# [198047 rows x 9 columns]

# %%
turnstiles_daily.DAILY_ENTRIES.describe()
# Out:
# count    198047.000000
# mean       1045.580615
# std         983.224000
# min           0.000000
# 25%         269.000000
# 50%         802.000000
# 75%        1567.000000
# max        5991.000000
# Name: DAILY_ENTRIES, dtype: float64

# %%
turnstiles_daily
# Out:
#           C/A  UNIT       SCP        STATION        DATE  ENTRIES   PREV_DATE  \
# 1        A002  R051  02-00-00          59 ST  05/12/2019  7054669  05/11/2019
# 2        A002  R051  02-00-00          59 ST  05/13/2019  7055964  05/12/2019
# 3        A002  R051  02-00-00          59 ST  05/14/2019  7057449  05/13/2019
# 4        A002  R051  02-00-00          59 ST  05/15/2019  7059011  05/14/2019
# 5        A002  R051  02-00-00          59 ST  05/16/2019  7060696  05/15/2019
# ...       ...   ...       ...            ...         ...      ...         ...
# 203437  TRAM2  R469  00-05-01  RIT-ROOSEVELT  06/17/2019     5554  06/16/2019
# 203438  TRAM2  R469  00-05-01  RIT-ROOSEVELT  06/18/2019     5554  06/17/2019
# 203439  TRAM2  R469  00-05-01  RIT-ROOSEVELT  06/19/2019     5554  06/18/2019
# 203440  TRAM2  R469  00-05-01  RIT-ROOSEVELT  06/20/2019     5554  06/19/2019
# 203441  TRAM2  R469  00-05-01  RIT-ROOSEVELT  06/21/2019     5554  06/20/2019
#
#         PREV_ENTRIES  DAILY_ENTRIES
# 1          7054133.0            536
# 2          7054669.0           1295
# 3          7055964.0           1485
# 4          7057449.0           1562
# 5          7059011.0           1685
# ...              ...            ...
# 203437        5554.0              0
# 203438        5554.0              0
# 203439        5554.0              0
# 203440        5554.0              0
# 203441        5554.0              0
#
# [198047 rows x 9 columns]

# %%
turnstiles_daily.groupby(['STATION']).DAILY_ENTRIES.sum().sort_values(ascending=False).head(50)
# Out:
# STATION
# 34 ST-PENN STA     6095697
# 34 ST-HERALD SQ    4531066
# 23 ST              4113105
# 42 ST-PORT AUTH    3879506
# TIMES SQ-42 ST     3742222
# GRD CNTRL-42 ST    3742092
# 14 ST-UNION SQ     3530528
# FULTON ST          3429380
# 86 ST              3123159
# 125 ST             2946830
# CANAL ST           2832895
# 59 ST COLUMBUS     2538748
# 96 ST              2402542
# 59 ST              2352049
# 14 ST              2319748
# 47-50 STS ROCK     2113110
# FLUSHING-MAIN      2110871
# CHAMBERS ST        2004097
# JKSN HT-ROOSVLT    1899060
# 50 ST              1894117
# PATH NEW WTC       1811057
# 72 ST              1807713
# 28 ST              1658940
# ATL AV-BARCLAY     1625149
# W 4 ST-WASH SQ     1548076
# 42 ST-BRYANT PK    1529675
# WALL ST            1493888
# 7 AV               1481361
# LEXINGTON AV/53    1474689
# JAY ST-METROTEC    1406195
# 8 AV               1348810
# 145 ST             1313371
# CHURCH AV          1311325
# 116 ST             1218223
# BOROUGH HALL       1198932
# DEKALB AV          1172939
# GRAND ST           1156656
# 57 ST-7 AV         1148675
# 77 ST              1119909
# JAMAICA CENTER     1116275
# 72 ST-2 AVE        1109203
# 103 ST             1076891
# 161/YANKEE STAD    1076842
# DELANCEY/ESSEX     1041048
# BOWLING GREEN      1034053
# 33 ST              1012191
# KINGS HWY          1004540
# 86 ST-2 AVE         978780
# SPRING ST           968126
# CROWN HTS-UTICA     961987
# Name: DAILY_ENTRIES, dtype: int64

# %%
boroughs = pd.read_csv('http://web.mta.info/developers/data/nyct/subway/Stations.csv')
boroughs
# Out:
#      Station ID  Complex ID GTFS Stop ID Division           Line  \
# 0             1           1          R01      BMT        Astoria
# 1             2           2          R03      BMT        Astoria
# 2             3           3          R04      BMT        Astoria
# 3             4           4          R05      BMT        Astoria
# 4             5           5          R06      BMT        Astoria
# ..          ...         ...          ...      ...            ...
# 491         517         517          S15      SIR  Staten Island
# 492         518         518          S14      SIR  Staten Island
# 493         519         519          S13      SIR  Staten Island
# 494         522         522          S09      SIR  Staten Island
# 495         523         523          S11      SIR  Staten Island
#
#                   Stop Name Borough Daytime Routes   Structure  GTFS Latitude  \
# 0    Astoria - Ditmars Blvd       Q            N W    Elevated      40.775036
# 1              Astoria Blvd       Q            N W    Elevated      40.770258
# 2                     30 Av       Q            N W    Elevated      40.766779
# 3                  Broadway       Q            N W    Elevated      40.761820
# 4                     36 Av       Q            N W    Elevated      40.756804
# ..                      ...     ...            ...         ...            ...
# 491            Prince's Bay      SI            SIR    Open Cut      40.525507
# 492         Pleasant Plains      SI            SIR  Embankment      40.522410
# 493         Richmond Valley      SI            SIR    Open Cut      40.519631
# 494             Tottenville      SI            SIR    At Grade      40.512764
# 495             Arthur Kill      SI            SIR    At Grade      40.516578
#
#      GTFS Longitude   North Direction Label South Direction Label
# 0        -73.912034                     NaN             Manhattan
# 1        -73.917843            Ditmars Blvd             Manhattan
# 2        -73.921479  Astoria - Ditmars Blvd             Manhattan
# 3        -73.925508  Astoria - Ditmars Blvd             Manhattan
# 4        -73.929575  Astoria - Ditmars Blvd             Manhattan
# ..              ...                     ...                   ...
# 491      -74.200064               St George           Tottenville
# 492      -74.217847               St George           Tottenville
# 493      -74.229141               St George           Tottenville
# 494      -74.251961               St George                   NaN
# 495      -74.242096               St George           Tottenville
#
# [496 rows x 13 columns]

# %%
boroughs['Stop Name'] = boroughs['Stop Name'].str.upper()

# %%
boroughs
# Out:
#      Station ID  Complex ID GTFS Stop ID Division           Line  \
# 0             1           1          R01      BMT        Astoria
# 1             2           2          R03      BMT        Astoria
# 2             3           3          R04      BMT        Astoria
# 3             4           4          R05      BMT        Astoria
# 4             5           5          R06      BMT        Astoria
# ..          ...         ...          ...      ...            ...
# 491         517         517          S15      SIR  Staten Island
# 492         518         518          S14      SIR  Staten Island
# 493         519         519          S13      SIR  Staten Island
# 494         522         522          S09      SIR  Staten Island
# 495         523         523          S11      SIR  Staten Island
#
#                   Stop Name Borough Daytime Routes   Structure  GTFS Latitude  \
# 0    ASTORIA - DITMARS BLVD       Q            N W    Elevated      40.775036
# 1              ASTORIA BLVD       Q            N W    Elevated      40.770258
# 2                     30 AV       Q            N W    Elevated      40.766779
# 3                  BROADWAY       Q            N W    Elevated      40.761820
# 4                     36 AV       Q            N W    Elevated      40.756804
# ..                      ...     ...            ...         ...            ...
# 491            PRINCE'S BAY      SI            SIR    Open Cut      40.525507
# 492         PLEASANT PLAINS      SI            SIR  Embankment      40.522410
# 493         RICHMOND VALLEY      SI            SIR    Open Cut      40.519631
# 494             TOTTENVILLE      SI            SIR    At Grade      40.512764
# 495             ARTHUR KILL      SI            SIR    At Grade      40.516578
#
#      GTFS Longitude   North Direction Label South Direction Label
# 0        -73.912034                     NaN             Manhattan
# 1        -73.917843            Ditmars Blvd             Manhattan
# 2        -73.921479  Astoria - Ditmars Blvd             Manhattan
# 3        -73.925508  Astoria - Ditmars Blvd             Manhattan
# 4        -73.929575  Astoria - Ditmars Blvd             Manhattan
# ..              ...                     ...                   ...
# 491      -74.200064               St George           Tottenville
# 492      -74.217847               St George           Tottenville
# 493      -74.229141               St George           Tottenville
# 494      -74.251961               St George                   NaN
# 495      -74.242096               St George           Tottenville
#
# [496 rows x 13 columns]

# %%
turnstiles_daily.STATION.unique() in boroughs['Stop Name'].unique()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   """Entry point for launching an IPython kernel.
# False

# %%
boroughs = boroughs.loc[: ,['Stop Name', 'Borough']]

# %%
boroughs.columns = ['STATION', 'Borough']

# %%
merged_df = turnstiles_daily.merge(right=boroughs, on='STATION', how='left')

# %%
merged_df.sort_values(by='DAILY_ENTRIES', ascending=False)
# Out:
#           C/A  UNIT       SCP          STATION        DATE   ENTRIES  \
# 57117    H009  R235  00-03-04       BEDFORD AV  05/21/2019  10853576
# 57137    H009  R235  00-03-04       BEDFORD AV  06/14/2019  10975059
# 298642   R513  R093  00-03-02            30 AV  05/15/2019   1233141
# 158954   N506  R022  00-05-05  34 ST-HERALD SQ  05/31/2019    929976
# 259861   R240  R047  00-03-08  GRD CNTRL-42 ST  05/14/2019  38370928
# ...       ...   ...       ...              ...         ...       ...
# 38484    C009  R057  03-05-01   ATL AV-BARCLAY  06/14/2019       761
# 38485    C009  R057  03-05-01   ATL AV-BARCLAY  06/15/2019       761
# 38486    C009  R057  03-05-01   ATL AV-BARCLAY  06/16/2019       761
# 38487    C009  R057  03-05-01   ATL AV-BARCLAY  06/17/2019       761
# 322937  TRAM2  R469  00-05-01    RIT-ROOSEVELT  06/21/2019      5554
#
#          PREV_DATE  PREV_ENTRIES  DAILY_ENTRIES Borough
# 57117   05/20/2019    10847585.0           5991      Bk
# 57137   06/13/2019    10969071.0           5988      Bk
# 298642  05/14/2019     1227153.0           5988       Q
# 158954  05/30/2019      923993.0           5983     NaN
# 259861  05/13/2019    38364953.0           5975     NaN
# ...            ...           ...            ...     ...
# 38484   06/13/2019         761.0              0     NaN
# 38485   06/14/2019         761.0              0     NaN
# 38486   06/15/2019         761.0              0     NaN
# 38487   06/16/2019         761.0              0     NaN
# 322937  06/20/2019        5554.0              0     NaN
#
# [322938 rows x 10 columns]

# %%
'34 ST-HERALD SQ' in boroughs.STATION.unique()
# Out:
# False

# %%
turnstiles_daily
# Out:
#           C/A  UNIT       SCP        STATION        DATE  ENTRIES   PREV_DATE  \
# 1        A002  R051  02-00-00          59 ST  05/12/2019  7054669  05/11/2019
# 2        A002  R051  02-00-00          59 ST  05/13/2019  7055964  05/12/2019
# 3        A002  R051  02-00-00          59 ST  05/14/2019  7057449  05/13/2019
# 4        A002  R051  02-00-00          59 ST  05/15/2019  7059011  05/14/2019
# 5        A002  R051  02-00-00          59 ST  05/16/2019  7060696  05/15/2019
# ...       ...   ...       ...            ...         ...      ...         ...
# 203437  TRAM2  R469  00-05-01  RIT-ROOSEVELT  06/17/2019     5554  06/16/2019
# 203438  TRAM2  R469  00-05-01  RIT-ROOSEVELT  06/18/2019     5554  06/17/2019
# 203439  TRAM2  R469  00-05-01  RIT-ROOSEVELT  06/19/2019     5554  06/18/2019
# 203440  TRAM2  R469  00-05-01  RIT-ROOSEVELT  06/20/2019     5554  06/19/2019
# 203441  TRAM2  R469  00-05-01  RIT-ROOSEVELT  06/21/2019     5554  06/20/2019
#
#         PREV_ENTRIES  DAILY_ENTRIES
# 1          7054133.0            536
# 2          7054669.0           1295
# 3          7055964.0           1485
# 4          7057449.0           1562
# 5          7059011.0           1685
# ...              ...            ...
# 203437        5554.0              0
# 203438        5554.0              0
# 203439        5554.0              0
# 203440        5554.0              0
# 203441        5554.0              0
#
# [198047 rows x 9 columns]

# %%
turnstiles_daily['DATE'] = pd.to_datetime(turnstiles_daily['DATE'])
turnstiles_daily['DAY'] = turnstiles_daily['DATE'].dt.dayofweek
turnstiles_daily['DATE'].dt.week
turnstiles_daily['WEEK_NUMBER'] = turnstiles_daily['DATE'].dt.week

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
filt = (turnstiles_daily['STATION'] == '34 ST-PENN STA')
station_penn = turnstiles_daily[filt]
station_penn_day = station_penn.groupby(['STATION','DAY']).DAILY_ENTRIES.sum().reset_index()
station_penn_list = []
for elem in station_penn_day['DAILY_ENTRIES']:
    station_penn_list.append(elem)

# %%
filt2 = (turnstiles_daily['STATION'] == '34 ST-HERALD SQ')
station_herald = turnstiles_daily[filt2]
station_herald_day = station_herald.groupby(['STATION','DAY']).DAILY_ENTRIES.sum().reset_index()
station_herald_list = []
for elem in station_herald_day['DAILY_ENTRIES']:
    station_herald_list.append(elem)

# %%
filt3 = (turnstiles_daily['STATION'] == '23 ST')
station_23 = turnstiles_daily[filt3]
station_23_day = station_23.groupby(['STATION','DAY']).DAILY_ENTRIES.sum().reset_index()
station_23_list = []
for elem in station_23_day['DAILY_ENTRIES']:
    station_23_list.append(elem)

# %%
filt4 = (turnstiles_daily['STATION'] == '42 ST-PORT AUTH')
station_port = turnstiles_daily[filt4]
station_port_day = station_port.groupby(['STATION','DAY']).DAILY_ENTRIES.sum().reset_index()
station_port_list = []
for elem in station_port_day['DAILY_ENTRIES']:
    station_port_list.append(elem)

# %%
filt5 = (turnstiles_daily['STATION'] == 'TIMES SQ-42 ST')
station_times = turnstiles_daily[filt5]
station_times_day = station_times.groupby(['STATION','DAY']).DAILY_ENTRIES.sum().reset_index()
station_times_list = []
for elem in station_times_day['DAILY_ENTRIES']:
    station_times_list.append(elem)

# %%
#manhattan bar graph
plotdata = pd.DataFrame({
    "34 ST-PENN STA":station_penn_list,
    "34 ST-HERALD SQ":station_herald_list,
    "23 ST":station_23_list,
    "42 ST-PORT AUTH":station_port_list,
    "TIMES SQ-42 ST":station_times_list
    }, 
    index=["Monday", 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])

plotdata.plot(kind="bar")
plt.xticks(fontsize=10, rotation='horizontal')
plt.yticks(fontsize=10)
plt.xlabel('Day of Week', fontsize=10)
plt.ylabel('Total Entry', fontsize=10)
plt.title('Manhattan',fontsize=15,weight='bold');
    
#line graph for average across stations per day    
plotdata['mean'] = plotdata.mean(axis=1)
mean_list = []
for elem in plotdata['mean']:
    mean_list.append(elem)
plt.plot(mean_list,'k');

# manhattan top 5 stations by volume
# 1. 34 ST-PENN STA
# 2. 34 ST-HERALD SQ
# 3. 23 ST
# 4. 42 ST-PORT AUTH
# 5. TIMES SQ-42 ST

# %%
filt6 = (turnstiles_daily['STATION'] == '59 ST')
station_59 = turnstiles_daily[filt6]
station_59_day = station_59.groupby(['STATION','DAY']).DAILY_ENTRIES.sum().reset_index()
station_59_list = []
for elem in station_59_day['DAILY_ENTRIES']:
    station_59_list.append(elem)

# %%
filt7 = (turnstiles_daily['STATION'] == 'ATL AV-BARCLAY')
station_atl = turnstiles_daily[filt7]
station_atl_day = station_atl.groupby(['STATION','DAY']).DAILY_ENTRIES.sum().reset_index()
station_atl_list = []
for elem in station_atl_day['DAILY_ENTRIES']:
    station_atl_list.append(elem)

# %%
filt8 = (turnstiles_daily['STATION'] == 'JAY ST-METROTEC')
station_jay = turnstiles_daily[filt8]
station_jay_day = station_jay.groupby(['STATION','DAY']).DAILY_ENTRIES.sum().reset_index()
station_jay_list = []
for elem in station_jay_day['DAILY_ENTRIES']:
    station_jay_list.append(elem)

# %%
filt9 = (turnstiles_daily['STATION'] == 'CHURCH AV')
station_church = turnstiles_daily[filt9]
station_church_day = station_church.groupby(['STATION','DAY']).DAILY_ENTRIES.sum().reset_index()
station_church_list = []
for elem in station_church_day['DAILY_ENTRIES']:
    station_church_list.append(elem)

# %%
filt10 = (turnstiles_daily['STATION'] == 'BOROUGH HALL')
station_borough = turnstiles_daily[filt10]
station_borough_day = station_borough.groupby(['STATION','DAY']).DAILY_ENTRIES.sum().reset_index()
station_borough_list = []
for elem in station_borough_day['DAILY_ENTRIES']:
    station_borough_list.append(elem)

# %%
#brooklyn bar graph
plotdata2 = pd.DataFrame({
    "59 ST":station_59_list,
    "ATL AV-BARCLAY":station_atl_list,
    "JAY ST-METROTEC":station_jay_list,
    "CHURCH AV":station_church_list,
    "BOROUGH HALL":station_borough_list
    }, 
    index=["Monday", 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])

plotdata2.plot(kind="bar")
plt.xticks(fontsize=10, rotation='horizontal')
plt.yticks(fontsize=10)
plt.xlabel('Day of Week', fontsize=10)
plt.ylabel('Total Entry', fontsize=10)
plt.title('Brooklyn',fontsize=15,weight='bold');

#line graph for average across stations per day
plotdata2['mean'] = plotdata2.mean(axis=1)
mean_list = []
for elem in plotdata2['mean']:
    mean_list.append(elem)
plt.plot(mean_list,'k');

# brooklyn top 5 stations by volume
# 1. 59 ST
# 2. ATL AV-BARCLAY
# 3. JAY ST-METROTEC
# 4. CHURCH AV
# 5. BOROUGH HALL
